# %%
import paddle
# Out:
# E:\anaconda3\envs\PaddlePaddle\Lib\site-packages\paddle\utils\cpp_extension\extension_utils.py:718: UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
#   warnings.warn(warning_message)

# %%
paddle.utils.run_check()
# Out:
# Running verify PaddlePaddle program ...
# E:\anaconda3\envs\PaddlePaddle\Lib\site-packages\paddle\pir\math_op_patch.py:219: UserWarning: Value do not have 'place' interface for pir graph mode, try not to use it. None will be returned.
#   warnings.warn(
# PaddlePaddle works well on 1 GPU.
# PaddlePaddle is installed successfully! Let's start deep learning with PaddlePaddle now.

# %%
# 1. 验证 Paddle 导入+GPU 可用性（必须输出 True 才正常）
import paddle
print("Paddle 版本：", paddle.__version__)
print("GPU 是否可用：", paddle.is_compiled_with_cuda())
print("GPU 数量：", paddle.device.cuda.device_count())

# 2. 验证当前内核是 Paddle GPU 环境（路径应指向 E:\anaconda3\envs\PaddlePaddle\python.exe）
import sys
print("当前 Python 路径：", sys.executable)
# Out:
# Paddle 版本： 3.2.2
# GPU 是否可用： True
# GPU 数量： 1
# 当前 Python 路径： E:\anaconda3\envs\PaddlePaddle\python.exe

# %%
# !git --version
# Out:
# git version 2.52.0.windows.1

# %%
# 测试是否安装成功
# !python ppdet/modeling/tests/test_architectures.py
# Out:
# python: can't open file 'E:\\DesktopFile\\Python\\jupyter_notebook_files\\ppdet\\modeling\\tests\\test_architectures.py': [Errno 2] No such file or directory

# %%
# 切换到 E 盘根目录（纯路径，无注释）
# %cd E:/
# Out:
# E:\

# %%
# !python ppdet/modeling/tests/test_architectures.py
# Out:
# python: can't open file 'E:\\ppdet\\modeling\\tests\\test_architectures.py': [Errno 2] No such file or directory

# %%
# %cd E:/PaddleDetection
# Out:
# E:\PaddleDetection

# %%
# !python ppdet/modeling/tests/test_architectures.py
# Out:
# Warning: Unable to use numba in PP-Tracking, please install numba, for example(python3.7): `pip install numba==0.56.4`
# Warning: Unable to use numba in PP-Tracking, please install numba, for example(python3.7): `pip install numba==0.56.4`
# [12/20 22:20:54] ppdet.utils.checkpoint INFO: Skipping import of the encryption module.
# INFO: Could not find files for the given pattern(s).
# E:\anaconda3\envs\PaddlePaddle\Lib\site-packages\paddle\utils\cpp_extension\extension_utils.py:718: UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
#   warnings.warn(warning_message)
# WARNING: Logging before InitGoogleLogging() is written to STDERR
# W1220 22:20:55.800635  4396 gpu_resources.cc:114] Please NOTE: device: 0, GPU Compute Capability: 8.6, Driver API Version: 12.3, Runtime API Version: 12.9
# .......
# ----------------------------------------------------------------------
# Ran 7 tests in 1.406s
#
# OK

# %%
# !export CUDA_VISIBLE_DEVICES=0
# !wget -P demo_input -N https://paddledet.bj.bcebos.com/modelcenter/images/General/000000014439.jpg
# !python tools/infer.py -c configs/ppyolo/ppyolo_r50vd_dcn_1x_coco.yml -o use_gpu=true weights=https://paddledet.bj.bcebos.com/models/ppyolo_r50vd_dcn_1x_coco.pdparams --infer_img=demo_input/000000014439.jpg
# Out:
# 'export' is not recognized as an internal or external command,
# operable program or batch file.
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.
# Warning: Unable to use numba in PP-Tracking, please install numba, for example(python3.7): `pip install numba==0.56.4`
# Warning: Unable to use numba in PP-Tracking, please install numba, for example(python3.7): `pip install numba==0.56.4`
# [12/20 22:22:34] ppdet.utils.checkpoint INFO: Skipping import of the encryption module.
# [12/20 22:22:40] ppdet.utils.checkpoint INFO: Finish loading model weights: C:\Users\haoran/.cache/paddle/weights\ppyolo_r50vd_dcn_1x_coco.pdparams
# INFO: Could not find files for the given pattern(s).
# WARNING: Logging before InitGoogleLogging() is written to STDERR
# W1220 22:22:35.794186  9664 gpu_resources.cc:114] Please NOTE: device: 0, GPU Compute Capability: 8.6, Driver API Version: 12.3, Runtime API Version: 12.9
# Traceback (most recent call last):
#   File "E:\PaddleDetection\tools\infer.py", line 280, in <module>
#     main()
#   File "E:\PaddleDetection\tools\infer.py", line 276, in main
#     run(FLAGS, cfg)
#   File "E:\PaddleDetection\tools\infer.py", line 202, in run
#     images = get_test_images(FLAGS.infer_dir, FLAGS.infer_img, FLAGS.infer_list)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "E:\PaddleDetection\tools\infer.py", line 154, in get_test_images
#     assert infer_img is None or os.path.isfile(infer_img), \
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: demo_input/000000014439.jpg is not a file

# %%
use_gpu: true # 是否使用GPU
log_iter: 20  # 每多少个迭代次显示
save_dir: output # 模型保存目录
snapshot_epoch: 1 # 多少个epoch保存一次
print_flops: false
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 use_gpu: true # 是否使用GPU
#       2 log_iter: 20  # 每多少个迭代次显示
#       3 save_dir: output # 模型保存目录
#
# NameError: name 'true' is not defined

# %%
# %cd ~/work/PaddleDetection/
# %env CUDA_VISIBLE_DEVICES=0
#开始训练
# !python  tools/train.py -c configs/ppyolo/ppyolov2_r50vd_dcn_365e_coco.yml  --use_vdl=true
# Out:
# [WinError 3] 系统找不到指定的路径。: 'C:\\Users\\haoran/work/PaddleDetection/'
# E:\PaddleDetection
# env: CUDA_VISIBLE_DEVICES=0
# Warning: Unable to use numba in PP-Tracking, please install numba, for example(python3.7): `pip install numba==0.56.4`
# Warning: Unable to use numba in PP-Tracking, please install numba, for example(python3.7): `pip install numba==0.56.4`
# [12/21 00:04:50] ppdet.utils.checkpoint INFO: Skipping import of the encryption module.
# [12/21 00:04:50] ppdet.utils.download WARNING: Config image_dir dataset/bit_vehicle\annotations/train/images is not a directory, dataset config is not valid
# INFO: Could not find files for the given pattern(s).
# ======================= Modified FLAGS detected =======================
# FLAGS(name='FLAGS_enable_pir_in_executor', current_value=True, default_value=False)
# FLAGS(name='FLAGS_win_cuda_bin_dir', current_value='E:\\anaconda3\\envs\\PaddlePaddle\\Lib\\site-packages\\paddle\\..\\nvidia', default_value='')
# =======================================================================
# Traceback (most recent call last):
#   File "E:\PaddleDetection\tools\train.py", line 212, in <module>
#     main()
#   File "E:\PaddleDetection\tools\train.py", line 208, in main
#     run(FLAGS, cfg)
#   File "E:\PaddleDetection\tools\train.py", line 148, in run
#     trainer = Trainer(cfg, mode='train')
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "E:\PaddleDetection\ppdet\engine\trainer.py", line 123, in __init__
#     self.loader = create('{}Reader'.format(capital_mode))(
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "E:\PaddleDetection\ppdet\data\reader.py", line 189, in __call__
#     self.dataset.check_or_download_dataset()
#   File "E:\PaddleDetection\ppdet\data\source\dataset.py", line 116, in check_or_download_dataset
#     self.dataset_dir = get_dataset_path(self.dataset_dir, self.anno_path,
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "E:\PaddleDetection\ppdet\utils\download.py", line 191, in get_dataset_path
#     raise ValueError(
# ValueError: Dataset E:\PaddleDetection\dataset\bit_vehicle is not valid for reason above, please check again.

# %%
# %cd E:\PaddleDetection
# %env CUDA_VISIBLE_DEVICES=0
#开始训练
# !python  tools/train.py -c configs/ppyolo/ppyolov2_r50vd_dcn_365e_coco.yml  --use_vdl=true
# Out:
# E:\PaddleDetection
# env: CUDA_VISIBLE_DEVICES=0
# Warning: Unable to use numba in PP-Tracking, please install numba, for example(python3.7): `pip install numba==0.56.4`
# Warning: Unable to use numba in PP-Tracking, please install numba, for example(python3.7): `pip install numba==0.56.4`
# [12/21 00:09:09] ppdet.utils.checkpoint INFO: Skipping import of the encryption module.
# loading annotations into memory...
# Done (t=0.08s)
# creating index...
# index created!
# [12/21 00:09:12] ppdet.data.source.coco INFO: Load [7880 samples valid, 0 samples invalid] in file dataset/bit_vehicle\annotations/bit_vehicle_train_coco.json.
# [12/21 00:09:13] ppdet.utils.download INFO: Downloading ResNet50_vd_ssld_pretrained.pdparams from https://paddledet.bj.bcebos.com/models/pretrained/ResNet50_vd_ssld_pretrained.pdparams
# [12/21 00:10:02] ppdet.utils.checkpoint INFO: Finish loading model weights: C:\Users\haoran/.cache/paddle/weights\ResNet50_vd_ssld_pretrained.pdparams
# [12/21 00:10:16] ppdet.engine.callbacks INFO: Epoch: [0] [  0/656] learning_rate: 0.000000 loss_xy: 0.930945 loss_wh: 2.841991 loss_iou: 3.461558 loss_iou_aware: 0.631627 loss_obj: 12838.763672 loss_cls: 4.838513 loss: 12851.468750 eta: 38 days, 10:11:34 batch_cost: 13.8652 data_cost: 0.0112 ips: 0.8655 images/s, max_mem_reserved: 10018 MB, max_mem_allocated: 8845 MB
# INFO: Could not find files for the given pattern(s).
# ======================= Modified FLAGS detected =======================
# FLAGS(name='FLAGS_enable_pir_in_executor', current_value=True, default_value=False)
# FLAGS(name='FLAGS_win_cuda_bin_dir', current_value='E:\\anaconda3\\envs\\PaddlePaddle\\Lib\\site-packages\\paddle\\..\\nvidia', default_value='')
# =======================================================================
# WARNING: Logging before InitGoogleLogging() is written to STDERR
# W1221 00:09:12.883030 18880 gpu_resources.cc:114] Please NOTE: device: 0, GPU Compute Capability: 8.6, Driver API Version: 12.3, Runtime API Version: 12.9
#
#   0%|          | 0/138935 [00:00<?, ?KB/s]
#   0%|          | 16/138935 [00:00<18:51, 122.77KB/s]
#   0%|          | 48/138935 [00:00<14:33, 159.08KB/s]
#   0%|          | 64/138935 [00:00<17:01, 135.92KB/s]
#   0%|          | 80/138935 [00:00<17:47, 130.04KB/s]
#   0%|          | 112/138935 [00:00<14:53, 155.39KB/s]
#   0%|          | 128/138935 [00:00<16:28, 140.42KB/s]
#   0%|          | 160/138935 [00:01<14:36, 158.27KB/s]
#   0%|          | 192/138935 [00:01<13:53, 166.42KB/s]
#   0%|          | 224/138935 [00:01<12:51, 179.74KB/s]
#  91%|█████████ | 126122/138935 [00:38<00:03, 3728.24KB/s]
#  91%|█████████ | 126687/138935 [00:38<00:02, 4243.08KB/s]
#  91%|█████████▏| 127124/138935 [00:39<00:02, 4035.35KB/s]
#  92%|█████████▏| 127538/138935 [00:39<00:03, 3380.39KB/s]
#  92%|█████████▏| 127919/138935 [00:39<00:03, 3466.51KB/s]
#  92%|█████████▏| 128284/138935 [00:39<00:03, 3321.72KB/s]
#  93%|█████████▎| 128767/138935 [00:39<00:02, 3633.32KB/s]
#  93%|█████████▎| 129142/138935 [00:39<00:03, 2620.57KB/s]
#  93%|█████████▎| 129450/138935 [00:39<00:04, 2316.71KB/s]
#  93%|█████████▎| 129717/138935 [00:40<00:05, 1806.60KB/s]
#  94%|█████████▎| 129935/138935 [00:40<00:06, 1369.07KB/s]
#  94%|█████████▎| 130109/138935 [00:40<00:06, 1380.05KB/s]
#  94%|█████████▍| 130274/138935 [00:40<00:06, 1395.89KB/s]
#  94%|█████████▍| 130447/138935 [00:40<00:05, 1452.94KB/s]
#  94%|█████████▍| 130639/138935 [00:40<00:05, 1549.30KB/s]
#  94%|█████████▍| 130809/138935 [00:41<00:06, 1308.13KB/s]
#  94%|█████████▍| 131167/138935 [00:41<00:05, 1479.14KB/s]
#  95%|█████████▍| 131487/138935 [00:41<00:04, 1626.20KB/s]
#  95%|█████████▍| 131903/138935 [00:41<00:03, 2141.79KB/s]
#  95%|█████████▌| 132191/138935 [00:41<00:03, 2182.54KB/s]
#  95%|█████████▌| 132429/138935 [00:41<00:03, 1651.50KB/s]
#  95%|█████████▌| 132624/138935 [00:42<00:04, 1464.82KB/s]
#  96%|█████████▌| 133343/138935 [00:42<00:02, 2127.98KB/s]
#  96%|█████████▋| 133983/138935 [00:42<00:01, 2482.92KB/s]
#  97%|█████████▋| 135039/138935 [00:42<00:01, 3143.34KB/s]
#  97%|█████████▋| 135346/138935 [00:43<00:01, 2671.91KB/s]
#  98%|█████████▊| 135608/138935 [00:43<00:01, 2335.68KB/s]
#  98%|█████████▊| 136655/138935 [00:43<00:00, 3224.77KB/s]
#  99%|█████████▉| 137775/138935 [00:43<00:00, 3914.12KB/s]
# 100%|█████████▉| 138655/138935 [00:43<00:00, 4031.90KB/s]
# 100%|██████████| 138935/138935 [00:43<00:00, 3170.21KB/s]
# W1221 00:10:06.039178 18880 dygraph_functions.cc:97953] got different data type, run type promotion automatically, this may cause data type been changed.
# W1221 00:13:18.673156 18880 backward.cc:462] While running Node (AddGradNode) raises an EnforceNotMet exception

# %%
# %env CUDA_VISIBLE_DEVICES=0
#训练完以后，进行评估
# !python tools/eval.py -c configs/ppyolo/ppyolov2_r50vd_dcn_365e_coco.yml  -o use_gpu=true
# Out:
# env: CUDA_VISIBLE_DEVICES=0
# Warning: Unable to use numba in PP-Tracking, please install numba, for example(python3.7): `pip install numba==0.56.4`
# Warning: Unable to use numba in PP-Tracking, please install numba, for example(python3.7): `pip install numba==0.56.4`
# [12/21 14:33:12] ppdet.utils.checkpoint INFO: Skipping import of the encryption module.
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# [12/21 14:33:13] ppdet.data.source.coco INFO: Load [1970 samples valid, 0 samples invalid] in file dataset/bit_vehicle\annotations/bit_vehicle_val_coco.json.
# INFO: Could not find files for the given pattern(s).
# ======================= Modified FLAGS detected =======================
# FLAGS(name='FLAGS_enable_pir_in_executor', current_value=True, default_value=False)
# FLAGS(name='FLAGS_win_cuda_bin_dir', current_value='E:\\anaconda3\\envs\\PaddlePaddle\\Lib\\site-packages\\paddle\\..\\nvidia', default_value='')
# =======================================================================
# WARNING: Logging before InitGoogleLogging() is written to STDERR
# W1221 14:33:12.930975 24948 gpu_resources.cc:114] Please NOTE: device: 0, GPU Compute Capability: 8.6, Driver API Version: 12.3, Runtime API Version: 12.9
# Traceback (most recent call last):
#   File "E:\PaddleDetection\tools\eval.py", line 215, in <module>
#     main()
#   File "E:\PaddleDetection\tools\eval.py", line 211, in main
#     run(FLAGS, cfg)
#   File "E:\PaddleDetection\tools\eval.py", line 148, in run
#     trainer.load_weights(cfg.weights)
#   File "E:\PaddleDetection\ppdet\engine\trainer.py", line 474, in load_weights
#     load_pretrain_weight(self.model, weights, ARSL_eval)
#   File "E:\PaddleDetection\ppdet\utils\checkpoint.py", line 250, in load_pretrain_weight
#     raise ValueError("Model pretrain path `{}` does not exists. "
# ValueError: Model pretrain path `output/ppyolov2_r50vd_dcn_365e_coco/model_final` does not exists. If you don't want to load pretrain model, please delete `pretrain_weights` field in config file.

# %%
# %cd E:\PaddleDetection
# %env CUDA_VISIBLE_DEVICES=0
#训练完以后，进行评估
# !python tools/eval.py -c configs/ppyolo/ppyolov2_r50vd_dcn_365e_coco.yml  -o use_gpu=true
# Out:
# E:\PaddleDetection
# env: CUDA_VISIBLE_DEVICES=0
# Warning: Unable to use numba in PP-Tracking, please install numba, for example(python3.7): `pip install numba==0.56.4`
# Warning: Unable to use numba in PP-Tracking, please install numba, for example(python3.7): `pip install numba==0.56.4`
# [12/21 14:36:05] ppdet.utils.checkpoint INFO: Skipping import of the encryption module.
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# [12/21 14:36:07] ppdet.data.source.coco INFO: Load [1970 samples valid, 0 samples invalid] in file dataset/bit_vehicle\annotations/bit_vehicle_val_coco.json.
# INFO: Could not find files for the given pattern(s).
# ======================= Modified FLAGS detected =======================
# FLAGS(name='FLAGS_win_cuda_bin_dir', current_value='E:\\anaconda3\\envs\\PaddlePaddle\\Lib\\site-packages\\paddle\\..\\nvidia', default_value='')
# FLAGS(name='FLAGS_enable_pir_in_executor', current_value=True, default_value=False)
# =======================================================================
# WARNING: Logging before InitGoogleLogging() is written to STDERR
# W1221 14:36:06.536701 18948 gpu_resources.cc:114] Please NOTE: device: 0, GPU Compute Capability: 8.6, Driver API Version: 12.3, Runtime API Version: 12.9
# Traceback (most recent call last):
#   File "E:\PaddleDetection\tools\eval.py", line 215, in <module>
#     main()
#   File "E:\PaddleDetection\tools\eval.py", line 211, in main
#     run(FLAGS, cfg)
#   File "E:\PaddleDetection\tools\eval.py", line 148, in run
#     trainer.load_weights(cfg.weights)
#   File "E:\PaddleDetection\ppdet\engine\trainer.py", line 474, in load_weights
#     load_pretrain_weight(self.model, weights, ARSL_eval)
#   File "E:\PaddleDetection\ppdet\utils\checkpoint.py", line 250, in load_pretrain_weight
#     raise ValueError("Model pretrain path `{}` does not exists. "
# ValueError: Model pretrain path `output/ppyolov2_r50vd_dcn_365e_coco/model_final` does not exists. If you don't want to load pretrain model, please delete `pretrain_weights` field in config file.

# %%
# %cd E:\PaddleDetection
# %env CUDA_VISIBLE_DEVICES=0
#开始训练
# !python  tools/train.py -c configs/ppyolo/ppyolov2_r50vd_dcn_365e_coco.yml  --use_vdl=true
# Out:
# E:\PaddleDetection
# env: CUDA_VISIBLE_DEVICES=0
# Warning: Unable to use numba in PP-Tracking, please install numba, for example(python3.7): `pip install numba==0.56.4`
# Warning: Unable to use numba in PP-Tracking, please install numba, for example(python3.7): `pip install numba==0.56.4`
# [12/21 14:43:59] ppdet.utils.checkpoint INFO: Skipping import of the encryption module.
# INFO: Could not find files for the given pattern(s).
# Traceback (most recent call last):
#   File "E:\PaddleDetection\tools\train.py", line 212, in <module>
#     main()
#   File "E:\PaddleDetection\tools\train.py", line 166, in main
#     cfg = load_config(FLAGS.config)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "E:\PaddleDetection\ppdet\core\workspace.py", line 123, in load_config
#     cfg = _load_config_with_base(file_path)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "E:\PaddleDetection\ppdet\core\workspace.py", line 88, in _load_config_with_base
#     file_cfg = yaml.load(f, Loader=yaml.Loader)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\haoran\AppData\Roaming\Python\Python311\site-packages\yaml\__init__.py", line 79, in load
#     loader = Loader(stream)
#              ^^^^^^^^^^^^^^
#   File "C:\Users\haoran\AppData\Roaming\Python\Python311\site-packages\yaml\loader.py", line 44, in __init__
#     Reader.__init__(self, stream)
#   File "C:\Users\haoran\AppData\Roaming\Python\Python311\site-packages\yaml\reader.py", line 85, in __init__
#     self.determine_encoding()
#   File "C:\Users\haoran\AppData\Roaming\Python\Python311\site-packages\yaml\reader.py", line 124, in determine_encoding
#     self.update_raw()
#   File "C:\Users\haoran\AppData\Roaming\Python\Python311\site-packages\yaml\reader.py", line 178, in update_raw
#     data = self.stream.read(size)
#            ^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'gbk' codec can't decode byte 0xa1 in position 187: illegal multibyte sequence

# %%
# %cd E:\PaddleDetection
# %env CUDA_VISIBLE_DEVICES=0
#开始训练
# !python  tools/train.py -c configs/ppyolo/ppyolov2_r50vd_dcn_365e_coco.yml  --use_vdl=true
# Out:
# E:\PaddleDetection
# env: CUDA_VISIBLE_DEVICES=0
# Warning: Unable to use numba in PP-Tracking, please install numba, for example(python3.7): `pip install numba==0.56.4`
# Warning: Unable to use numba in PP-Tracking, please install numba, for example(python3.7): `pip install numba==0.56.4`
# [12/21 14:47:07] ppdet.utils.checkpoint INFO: Skipping import of the encryption module.
# [12/21 14:47:07] ppdet.utils.check ERROR: 'architecture' not specified in config file. Please set it in config file.
# INFO: Could not find files for the given pattern(s).

# %%
# %cd ~/work/PaddleDetection/
# %env CUDA_VISIBLE_DEVICES=0
#开始训练
# !python  tools/train.py -c configs/ppyolo/ppyolov2_r50vd_dcn_365e_coco.yml  --use_vdl=true
# Out:
# [WinError 3] 系统找不到指定的路径。: 'C:\\Users\\haoran/work/PaddleDetection/'
# E:\PaddleDetection
# env: CUDA_VISIBLE_DEVICES=0
# Warning: Unable to use numba in PP-Tracking, please install numba, for example(python3.7): `pip install numba==0.56.4`
# Warning: Unable to use numba in PP-Tracking, please install numba, for example(python3.7): `pip install numba==0.56.4`
# [12/21 14:48:37] ppdet.utils.checkpoint INFO: Skipping import of the encryption module.
# loading annotations into memory...
# Done (t=0.09s)
# creating index...
# index created!
# [12/21 14:48:41] ppdet.data.source.coco INFO: Load [7880 samples valid, 0 samples invalid] in file dataset/bit_vehicle\annotations/bit_vehicle_train_coco.json.
# [12/21 14:48:45] ppdet.utils.checkpoint INFO: Finish loading model weights: C:\Users\haoran/.cache/paddle/weights\ResNet50_vd_ssld_pretrained.pdparams
# INFO: Could not find files for the given pattern(s).
# ======================= Modified FLAGS detected =======================
# FLAGS(name='FLAGS_enable_pir_in_executor', current_value=True, default_value=False)
# FLAGS(name='FLAGS_win_cuda_bin_dir', current_value='E:\\anaconda3\\envs\\PaddlePaddle\\Lib\\site-packages\\paddle\\..\\nvidia', default_value='')
# =======================================================================
# WARNING: Logging before InitGoogleLogging() is written to STDERR
# W1221 14:48:41.293402 25264 gpu_resources.cc:114] Please NOTE: device: 0, GPU Compute Capability: 8.6, Driver API Version: 12.3, Runtime API Version: 12.9
# W1221 14:48:53.541559 25264 dygraph_functions.cc:97953] got different data type, run type promotion automatically, this may cause data type been changed.
# W1221 14:49:01.469435 25264 backward.cc:462] While running Node (BatchNormGradNode) raises an EnforceNotMet exception

# %%
# %cd E:\PaddleDetection
# %env CUDA_VISIBLE_DEVICES=0
#开始训练
# !python  tools/train.py -c configs/ppyolo/ppyolov2_r50vd_dcn_365e_coco.yml  --use_vdl=true
# Out:
# E:\PaddleDetection
# env: CUDA_VISIBLE_DEVICES=0
# Warning: Unable to use numba in PP-Tracking, please install numba, for example(python3.7): `pip install numba==0.56.4`
# Warning: Unable to use numba in PP-Tracking, please install numba, for example(python3.7): `pip install numba==0.56.4`
# [12/21 14:50:17] ppdet.utils.checkpoint INFO: Skipping import of the encryption module.
# loading annotations into memory...
# Done (t=0.07s)
# creating index...
# index created!
# [12/21 14:50:20] ppdet.data.source.coco INFO: Load [7880 samples valid, 0 samples invalid] in file dataset/bit_vehicle\annotations/bit_vehicle_train_coco.json.
# [12/21 14:50:25] ppdet.utils.checkpoint INFO: Finish loading model weights: C:\Users\haoran/.cache/paddle/weights\ResNet50_vd_ssld_pretrained.pdparams
# INFO: Could not find files for the given pattern(s).
# ======================= Modified FLAGS detected =======================
# FLAGS(name='FLAGS_enable_pir_in_executor', current_value=True, default_value=False)
# FLAGS(name='FLAGS_win_cuda_bin_dir', current_value='E:\\anaconda3\\envs\\PaddlePaddle\\Lib\\site-packages\\paddle\\..\\nvidia', default_value='')
# =======================================================================
# WARNING: Logging before InitGoogleLogging() is written to STDERR
# W1221 14:50:20.801482 12068 gpu_resources.cc:114] Please NOTE: device: 0, GPU Compute Capability: 8.6, Driver API Version: 12.3, Runtime API Version: 12.9
# W1221 14:50:35.912580 12068 dygraph_functions.cc:97953] got different data type, run type promotion automatically, this may cause data type been changed.
# W1221 14:50:41.758013 12068 backward.cc:462] While running Node (BatchNormGradNode) raises an EnforceNotMet exception

# %%
# %cd E:\PaddleDetection
# Out:
# E:\PaddleDetection

# %%
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_VISIBLE_DEVICES=0

# %%
# !python  tools/train.py -c configs/ppyolo/ppyolov2_r50vd_dcn_365e_coco.yml  --use_vdl=true
# Out:
# Warning: Unable to use numba in PP-Tracking, please install numba, for example(python3.7): `pip install numba==0.56.4`
# Warning: Unable to use numba in PP-Tracking, please install numba, for example(python3.7): `pip install numba==0.56.4`
# [12/22 16:57:26] ppdet.utils.checkpoint INFO: Skipping import of the encryption module.
# INFO: Could not find files for the given pattern(s).
# Traceback (most recent call last):
#   File "E:\PaddleDetection\tools\train.py", line 212, in <module>
#     main()
#   File "E:\PaddleDetection\tools\train.py", line 166, in main
#     cfg = load_config(FLAGS.config)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "E:\PaddleDetection\ppdet\core\workspace.py", line 123, in load_config
#     cfg = _load_config_with_base(file_path)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "E:\PaddleDetection\ppdet\core\workspace.py", line 101, in _load_config_with_base
#     base_cfg = _load_config_with_base(base_yml)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "E:\PaddleDetection\ppdet\core\workspace.py", line 88, in _load_config_with_base
#     file_cfg = yaml.load(f, Loader=yaml.Loader)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\haoran\AppData\Roaming\Python\Python311\site-packages\yaml\__init__.py", line 81, in load
#     return loader.get_single_data()
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\haoran\AppData\Roaming\Python\Python311\site-packages\yaml\constructor.py", line 49, in get_single_data
#     node = self.get_single_node()
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\haoran\AppData\Roaming\Python\Python311\site-packages\yaml\composer.py", line 36, in get_single_node
#     document = self.compose_document()
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\haoran\AppData\Roaming\Python\Python311\site-packages\yaml\composer.py", line 55, in compose_document
#     node = self.compose_node(None, None)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\haoran\AppData\Roaming\Python\Python311\site-packages\yaml\composer.py", line 84, in compose_node
#     node = self.compose_mapping_node(anchor)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\haoran\AppData\Roaming\Python\Python311\site-packages\yaml\composer.py", line 127, in compose_mapping_node
#     while not self.check_event(MappingEndEvent):
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\haoran\AppData\Roaming\Python\Python311\site-packages\yaml\parser.py", line 98, in check_event
#     self.current_event = self.state()
#                          ^^^^^^^^^^^^
#   File "C:\Users\haoran\AppData\Roaming\Python\Python311\site-packages\yaml\parser.py", line 438, in parse_block_mapping_key
#     raise ParserError("while parsing a block mapping", self.marks[-1],
# yaml.parser.ParserError: while parsing a block mapping
#   in "configs/ppyolo\./_base_/optimizer_365e.yml", line 1, column 1
# expected <block end>, but found '<block mapping start>'
#   in "configs/ppyolo\./_base_/optimizer_365e.yml", line 5, column 3

# %%
# !python  tools/train.py -c configs/ppyolo/ppyolov2_r50vd_dcn_365e_coco.yml  --use_vdl=true
# Out:
# Warning: Unable to use numba in PP-Tracking, please install numba, for example(python3.7): `pip install numba==0.56.4`
# Warning: Unable to use numba in PP-Tracking, please install numba, for example(python3.7): `pip install numba==0.56.4`
# [12/22 17:02:24] ppdet.utils.checkpoint INFO: Skipping import of the encryption module.
# INFO: Could not find files for the given pattern(s).
# Traceback (most recent call last):
#   File "E:\PaddleDetection\tools\train.py", line 212, in <module>
#     main()
#   File "E:\PaddleDetection\tools\train.py", line 166, in main
#     cfg = load_config(FLAGS.config)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "E:\PaddleDetection\ppdet\core\workspace.py", line 123, in load_config
#     cfg = _load_config_with_base(file_path)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "E:\PaddleDetection\ppdet\core\workspace.py", line 101, in _load_config_with_base
#     base_cfg = _load_config_with_base(base_yml)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "E:\PaddleDetection\ppdet\core\workspace.py", line 88, in _load_config_with_base
#     file_cfg = yaml.load(f, Loader=yaml.Loader)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\haoran\AppData\Roaming\Python\Python311\site-packages\yaml\__init__.py", line 81, in load
#     return loader.get_single_data()
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\haoran\AppData\Roaming\Python\Python311\site-packages\yaml\constructor.py", line 49, in get_single_data
#     node = self.get_single_node()
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\haoran\AppData\Roaming\Python\Python311\site-packages\yaml\composer.py", line 36, in get_single_node
#     document = self.compose_document()
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\haoran\AppData\Roaming\Python\Python311\site-packages\yaml\composer.py", line 55, in compose_document
#     node = self.compose_node(None, None)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\haoran\AppData\Roaming\Python\Python311\site-packages\yaml\composer.py", line 84, in compose_node
#     node = self.compose_mapping_node(anchor)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\haoran\AppData\Roaming\Python\Python311\site-packages\yaml\composer.py", line 133, in compose_mapping_node
#     item_value = self.compose_node(node, item_key)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\haoran\AppData\Roaming\Python\Python311\site-packages\yaml\composer.py", line 84, in compose_node
#     node = self.compose_mapping_node(anchor)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\haoran\AppData\Roaming\Python\Python311\site-packages\yaml\composer.py", line 133, in compose_mapping_node
#     item_value = self.compose_node(node, item_key)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\haoran\AppData\Roaming\Python\Python311\site-packages\yaml\composer.py", line 82, in compose_node
#     node = self.compose_sequence_node(anchor)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\haoran\AppData\Roaming\Python\Python311\site-packages\yaml\composer.py", line 110, in compose_sequence_node
#     while not self.check_event(SequenceEndEvent):
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\haoran\AppData\Roaming\Python\Python311\site-packages\yaml\parser.py", line 98, in check_event
#     self.current_event = self.state()
#                          ^^^^^^^^^^^^
#   File "C:\Users\haoran\AppData\Roaming\Python\Python311\site-packages\yaml\parser.py", line 392, in parse_block_sequence_entry
#     raise ParserError("while parsing a block collection", self.marks[-1],
# yaml.parser.ParserError: while parsing a block collection
#   in "configs/ppyolo\./_base_/ppyolov2_reader.yml", line 14, column 5
# expected <block end>, but found '?'
#   in "configs/ppyolo\./_base_/ppyolov2_reader.yml", line 21, column 5

# %%
# !python  tools/train.py -c configs/ppyolo/ppyolov2_r50vd_dcn_365e_coco.yml  --use_vdl=true
# Out:
# Warning: Unable to use numba in PP-Tracking, please install numba, for example(python3.7): `pip install numba==0.56.4`
# Warning: Unable to use numba in PP-Tracking, please install numba, for example(python3.7): `pip install numba==0.56.4`
# [12/22 17:07:17] ppdet.utils.checkpoint INFO: Skipping import of the encryption module.
# INFO: Could not find files for the given pattern(s).
# Traceback (most recent call last):
#   File "E:\PaddleDetection\tools\train.py", line 212, in <module>
#     main()
#   File "E:\PaddleDetection\tools\train.py", line 166, in main
#     cfg = load_config(FLAGS.config)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "E:\PaddleDetection\ppdet\core\workspace.py", line 123, in load_config
#     cfg = _load_config_with_base(file_path)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "E:\PaddleDetection\ppdet\core\workspace.py", line 101, in _load_config_with_base
#     base_cfg = _load_config_with_base(base_yml)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "E:\PaddleDetection\ppdet\core\workspace.py", line 88, in _load_config_with_base
#     file_cfg = yaml.load(f, Loader=yaml.Loader)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\haoran\AppData\Roaming\Python\Python311\site-packages\yaml\__init__.py", line 79, in load
#     loader = Loader(stream)
#              ^^^^^^^^^^^^^^
#   File "C:\Users\haoran\AppData\Roaming\Python\Python311\site-packages\yaml\loader.py", line 44, in __init__
#     Reader.__init__(self, stream)
#   File "C:\Users\haoran\AppData\Roaming\Python\Python311\site-packages\yaml\reader.py", line 85, in __init__
#     self.determine_encoding()
#   File "C:\Users\haoran\AppData\Roaming\Python\Python311\site-packages\yaml\reader.py", line 124, in determine_encoding
#     self.update_raw()
#   File "C:\Users\haoran\AppData\Roaming\Python\Python311\site-packages\yaml\reader.py", line 178, in update_raw
#     data = self.stream.read(size)
#            ^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'gbk' codec can't decode byte 0xae in position 4: illegal multibyte sequence

# %%
# !python  tools/train.py -c configs/ppyolo/ppyolov2_r50vd_dcn_365e_coco.yml  --use_vdl=true
# Out:
# Warning: Unable to use numba in PP-Tracking, please install numba, for example(python3.7): `pip install numba==0.56.4`
# Warning: Unable to use numba in PP-Tracking, please install numba, for example(python3.7): `pip install numba==0.56.4`
# [12/22 17:10:03] ppdet.utils.checkpoint INFO: Skipping import of the encryption module.
# INFO: Could not find files for the given pattern(s).
# ======================= Modified FLAGS detected =======================
# FLAGS(name='FLAGS_win_cuda_bin_dir', current_value='E:\\anaconda3\\envs\\PaddlePaddle\\Lib\\site-packages\\paddle\\..\\nvidia', default_value='')
# FLAGS(name='FLAGS_enable_pir_in_executor', current_value=True, default_value=False)
# =======================================================================
# Traceback (most recent call last):
#   File "E:\PaddleDetection\tools\train.py", line 212, in <module>
#     main()
#   File "E:\PaddleDetection\tools\train.py", line 208, in main
#     run(FLAGS, cfg)
#   File "E:\PaddleDetection\tools\train.py", line 148, in run
#     trainer = Trainer(cfg, mode='train')
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "E:\PaddleDetection\ppdet\engine\trainer.py", line 123, in __init__
#     self.loader = create('{}Reader'.format(capital_mode))(
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "E:\PaddleDetection\ppdet\core\workspace.py", line 292, in create
#     return cls(**cls_kwargs)
#            ^^^^^^^^^^^^^^^^^
#   File "E:\PaddleDetection\ppdet\data\reader.py", line 259, in __init__
#     super(TrainReader, self).__init__(sample_transforms, batch_transforms,
#   File "E:\PaddleDetection\ppdet\data\reader.py", line 171, in __init__
#     self._sample_transforms = Compose(
#                               ^^^^^^^^
#   File "E:\PaddleDetection\ppdet\data\reader.py", line 50, in __init__
#     f = op_cls(**v)
#         ^^^^^^^^^^^
# TypeError: Mixup.__init__() got an unexpected keyword argument 'prob'

# %%
# !python  tools/train.py -c configs/ppyolo/ppyolov2_r50vd_dcn_365e_coco.yml  --use_vdl=true
